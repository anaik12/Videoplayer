# %%
import pyforms
from pyforms import BaseWidget
from pyforms.controls import ControlText, ControlButton, ControlDir, ControlFile, ControlFilesTree, ControlImage, ControlBoundingSlider
from pyforms.controls import ControlButton, ControlCheckBox, ControlCheckBoxList, ControlPlayer, ControlSlider
from pyforms import controls 
import glob
import cv2
import pims
from pims import ImageSequence, Video
from pylab import *

import numpy as np
import cv2

from PIL import Image

import os
from PIL import Image
import cv2
from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize, imshow
import glob
import matplotlib.pyplot as plt
# from glob import *

# print(glob.glob("C:\Workspace\CorrNet\w50_cor.70\images\*.gif"))

# %%
def make_video(images, outvid, fps=5, size=(1000, 1000),
               is_color=True, format="XVID"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
 
    The function relies on http://opencv-python-tutroals.readthedocs.org/en/latest/.
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
#         plt.imshow(img)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

# images1 = ImageSequence("C:\\Workspace\\VideoPlayer\\PROC\\*.tif")
# images = [cv2.imread(file) for file in glob.glob("C:\\Workspace\\VideoPlayer\\PROC\\*.tif")]
# images[100]
# images[0]
# images = glob.glob("C:\\Workspace\\VideoPlayer\\imagesCommdy1\\*.tif")
# images = glob.glob("C:\\Workspace\\VideoPlayer\\PROC\\*.tif")

# type(images1[0])

# image_list = []
# for filename in glob.glob('C:\\Workspace\\VideoPlayer\\PROC\\*.tif'): #assuming gif
#     im=Image.open(filename)
#     image_list.append(im)
    
# type(image_list)

# for i in range(10):
#     images[i]

# imshow(images)
# make_video(images)

# %%
from pathlib import Path

class VideoPlayer(BaseWidget):
    def __init__(self):
        super(VideoPlayer, self).__init__('Video Player')
        
        #Defnition of the form fields
        self.width = 200
        self.height = 200
#         self._dirname = ControlText('Directory', 'Default Value')
        self._button_play = ControlButton("Compare")
        self._button_play.value = self.__play_all
        
        self._button_pause = ControlButton("Pause")
        self._button_pause.value = self.__pause_all
        
        self._button_refresh = ControlButton("Reload")
        self._button_refresh.value = self.__refresh_all
        
        self._button_print = ControlButton("Print")
        self._button_print.value = self.__print_value
#         self.formset = [{'Tab1':['_dirname'],},'_button']
        
        self._directory1 = ControlDir('Choose a directory')
        self._directory2 = ControlDir('Choose a directory')
#         self._file1 = ControlFile('File 1')
#         self._file2 = ControlFile('File 2')
#     
       

#         self._filetree.value = 'C:\\Users\\Ashwini Naik\\Videos\\Captures'
        
#         self._checkbox = ControlCheckBox('Choose a directory')
#         self._checkboxList = ControlCheckBoxList('Choose a file')
        self._player = ControlPlayer()
        self._player1 = ControlPlayer()
#         self._slider = ControlSlider('Slider')
      
        
#         self._player.refresh()
        self.formset = [ ('_button_play','_button_pause','_button_refresh') ,('_directory1','_directory2'), ('_player','_player1')]
#         self._control.changed_event = self.__print_value
        self._value1 = "Video1.mp4"
        self._value2 = "Video2.mp4"

    
    def __print_value(self):
        print("Player 1" + self._player.value)
        print("Player 2" + self._player1.value)
        print("File 1" + self._file1.value)
        print("File 2" + self._file2.value)
        
    def __play_all(self):
        directory_path1 = Path(self._directory1.value)
        directory_path2 = Path(self._directory2.value)
        ext = '*.tif'
        imagepath1 = directory_path1 / ext
        imagepath2 = directory_path2 / ext
        print(imagepath1)
        images1 = glob.glob(str(imagepath1))
        images2 = glob.glob(str(imagepath2))
        
#         print(images1)
#         print(images2)
        
        make_video(images1, self._value1)
        
        make_video(images2, self._value2)

        self._player.show()
#         self._player.frame_width = 600.0
        self._player.value = self._value1
        
        self._player1.show()
#         self._player.frame_width = 600.0
        self._player1.value = self._value2
        
#         self._player.frame_width = 400.0
#         self._player1.frame_width = 400.0
#         self._player.frame_height = 400.0
#         self._player1.frame_height = 400.0
        
        self._player.play()
        self._player1.play()
            
    def __pause_all(self):
        if(self._player.is_playing and self._player1.is_playing):
            self._player.stop()
            self._player1.stop()
            self._button_pause.label = "Play"
        else:
            self._player.play()
            self._player1.play()
            self._button_pause.label = "Pause"
        
            
    def __refresh_all(self):
        self._player.value = self._value1
        self._player1.value = self._value2
            


#Execute the application

if __name__ == "__main__": 
    pyforms.start_app(VideoPlayer, geometry=(40, 50, 1600, 800) )
#     pyforms.start_app(VideoPlayer)
# Out:
# C:\Workspace\VideoPlayer\imagesCommdy1\*.tif

# %%
import os
from PIL import Image

yourpath = os.getcwd()
for root, dirs, files in os.walk(yourpath, topdown=False):
    for name in files:
        print(os.path.join(root, name))
        if os.path.splitext(os.path.join(root, name))[1].lower() == ".tif":
            if os.path.isfile(os.path.splitext(os.path.join(root, name))[0] + ".jpg"):
                print("A jpeg file already exists for %s" % name)
            # If a jpeg is *NOT* present, create one from the tiff.
            else:
                outfile = os.path.splitext(os.path.join(root, name))[0] + ".jpg"
#                 try:
                im = Image.open(os.path.join(root, name))
                print("Generating jpeg for %s" % name)
                im.thumbnail(im.size)
                im.save(outfile, "JPEG", quality=100)
#                 except(Exception, e:
#                     print(e)

# %% [raw]
# while(cap.isOpened()):
#     ret, frame = cap.read()
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#
#     cv2.imshow('frame',gray)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#
# cap.release()
# cv2.destroyAllWindows()

# %%
import numpy as np
import cv2

# %%
cap = cv2.VideoCapture('pngVideo2.mp4')
while(cap.isOpened()):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()

# %%
import os

basedir = 'C:\Workspace\VideoPlayer\imagesCommdy1'
ext = '*.tif'

fpath = os.path.join(basedir, ext)
print(fpath)
