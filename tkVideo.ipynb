# %%
import tkinter as tk
from tkinter import *

import gobject
import gst

root = Tk()
frame = Frame(root)

#
my_label = Label(root, text= "Hi").pack()
my_button =Button(root, text ="Open").pack()
root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a725d57771e2> in <module>()
#       3
#       4 import gobject
# ----> 5 import gst
#       6
#       7 root = Tk()
#
# ModuleNotFoundError: No module named 'gst'

# %%
import glob
print(glob.glob("C:\Workspace\CorrNet\w50_cor.70\images\*.gif"))
# Out:
# ['C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20000.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20001.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20002.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20003.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20004.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20005.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20006.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20007.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20008.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20009.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20010.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20011.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20012.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20013.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20014.gif', 'C:\\Workspace\\CorrNet\\w50_cor.70\\images\\cor_20015.gif', 'C:\\Workspace\\CorrN
# ...
